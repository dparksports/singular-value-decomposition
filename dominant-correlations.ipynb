# %%
from matplotlib.image import imread
import numpy as np
import matplotlib.pyplot as plt

# %%
A1 = imread("1_t.jpg")
A2 = imread("2_t.jpg")
A3 = imread("3_t.jpg")
A4 = imread("4_t.jpg")
A5 = imread("5_t.jpg")
A6 = imread("6_t.jpg")
A7 = imread("7_t.jpg")
A8 = imread("8_t.jpg")
A9 = imread("9_t.jpg")
A10 = imread("10_t.jpg")

A11 = imread("11_t.jpg")
A12 = imread("12_t.jpg")
A13 = imread("13_t.jpg")
A14 = imread("14_t.jpg")
A15 = imread("15_t.jpg")
A16 = imread("16_t.jpg")
A17 = imread("17_t.jpg")
A18 = imread("18_t.jpg")
A19 = imread("19_t.jpg")
A20 = imread("20_t.jpg")

A21 = imread("21_t.jpg")
A22 = imread("22_t.jpg")
A23 = imread("23_t.jpg")
A24 = imread("24_t.jpg")
A25 = imread("25_t.jpg")
A26 = imread("26_t.jpg")
A27 = imread("27_t.jpg")
A28 = imread("28_t.jpg")
A29 = imread("29_t.jpg")
A30 = imread("30_t.jpg")

# %%
X = np.vstack((A1.flatten(), A2.flatten(), A3.flatten(), A4.flatten(), A5.flatten(), A6.flatten(), A7.flatten(), A8.flatten(), A9.flatten(), A10.flatten(),
              A11.flatten(), A12.flatten(), A13.flatten(), A14.flatten(), A15.flatten(), A16.flatten(), A17.flatten(), A18.flatten(), A19.flatten(), A20.flatten(),
              A21.flatten(), A22.flatten(), A23.flatten(), A24.flatten(), A25.flatten(), A26.flatten(), A27.flatten(), A28.flatten(), A29.flatten(), A30.flatten()))
print(X.shape)
# Out:
# (30, 625)

# %%
U, S, V = np.linalg.svd(X,full_matrices=False)
S = np.diag(S)
VT = V.T
print(U.shape, S.shape, V.shape)
# Out:
# (30, 30) (30, 30) (30, 120000)

# %%
S = S * S
print(S)
# Out:
# [[5.36585670e+08]
#  [2.63553120e+07]
#  [2.34346876e+07]
#  [2.11338548e+07]
#  [1.42220724e+07]
#  [1.33263432e+07]
#  [1.13771564e+07]
#  [1.02362914e+07]
#  [8.86085669e+06]
#  [7.30743589e+06]
#  [6.69969720e+06]
#  [6.53936408e+06]
#  [6.13374431e+06]
#  [5.14941085e+06]
#  [4.86063060e+06]
#  [4.06001749e+06]
#  [3.81512570e+06]
#  [3.62846899e+06]
#  [3.41141427e+06]
#  [3.22407956e+06]
#  [2.72825862e+06]
#  [2.47432456e+06]
#  [2.26180184e+06]
#  [2.12005989e+06]
#  [1.94945964e+06]
#  [1.75638071e+06]
#  [1.23376914e+06]
#  [3.30676650e+05]
#  [2.55148956e+05]
#  [1.17790623e+05]]

# %%
corr = VT @ S @ V
print(Correlation.shape)
# Out:
# (625, 1)

# %%
eigenvector = corr[:,0]
print(eigenvector.shape)
# Out:
# (625,)

# %%
img = plt.imshow(eigenvector.reshape(25,25))
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
m,n = A1.shape[:2]
print(m,n)
# Out:
# 25 25

# %%
A1 = imread("20080101.jpg")
A2 = imread("20080102.jpg")
A3 = imread("20080103.jpg")
A4 = imread("20080104.jpg")
A5 = imread("20080105.jpg")
A6 = imread("20080106.jpg")
A7 = imread("20080107.jpg")
A8 = imread("20080108.jpg")
A9 = imread("20080109.jpg")
A10 = imread("20080110.jpg")

A11 = imread("20080111.jpg")
A12 = imread("20080112.jpg")
A13 = imread("20080113.jpg")
A14 = imread("20080114.jpg")
A15 = imread("20080115.jpg")
A16 = imread("20080116.jpg")
A17 = imread("20080117.jpg")
A18 = imread("20080118.jpg")
A19 = imread("20080119.jpg")
A20 = imread("20080120.jpg")

A21 = imread("20080121.jpg")
A22 = imread("20080122.jpg")
A23 = imread("20080123.jpg")
A24 = imread("20080124.jpg")
A25 = imread("20080125.jpg")
A26 = imread("20080126.jpg")
A27 = imread("20080127.jpg")
A28 = imread("20080128.jpg")
A29 = imread("20080129.jpg")
A30 = imread("20080130.jpg")

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
A1 = rgb2gray(A1)
A2 = rgb2gray(A2)
A3 = rgb2gray(A3)
A4 = rgb2gray(A4)
A5 = rgb2gray(A5)
A6 = rgb2gray(A6)
A7 = rgb2gray(A7)
A8 = rgb2gray(A8)
A9 = rgb2gray(A9)
A10 = rgb2gray(A10)
print(A1.shape)

A11 = rgb2gray(A11)
A12 = rgb2gray(A12)
A13 = rgb2gray(A13)
A14 = rgb2gray(A14)
A15 = rgb2gray(A15)
A16 = rgb2gray(A16)
A17 = rgb2gray(A17)
A18 = rgb2gray(A18)
A19 = rgb2gray(A19)
A20 = rgb2gray(A20)
print(A20.shape)

A21 = rgb2gray(A21)
A22 = rgb2gray(A22)
A23 = rgb2gray(A23)
A24 = rgb2gray(A24)
A25 = rgb2gray(A25)
A26 = rgb2gray(A26)
A27 = rgb2gray(A27)
A28 = rgb2gray(A28)
A29 = rgb2gray(A29)
A30 = rgb2gray(A30)
print(A20.shape)
# Out:
# (400, 300)
# (400, 300)
# (400, 300)

# %%
X = np.vstack((A1.flatten(), A2.flatten(), A3.flatten(), A4.flatten(), A5.flatten(), A6.flatten(), A7.flatten(), A8.flatten(), A9.flatten(), A10.flatten(),
              A11.flatten(), A12.flatten(), A13.flatten(), A14.flatten(), A15.flatten(), A16.flatten(), A17.flatten(), A18.flatten(), A19.flatten(), A20.flatten(),
              A21.flatten(), A22.flatten(), A23.flatten(), A24.flatten(), A25.flatten(), A26.flatten(), A27.flatten(), A28.flatten(), A29.flatten(), A30.flatten()))
print(X.shape)
# Out:
# (30, 120000)

# %%
U, S, V = np.linalg.svd(X,full_matrices=False)
VT = V.T
print(U.shape, V.shape, S.shape)
# Out:
# (30, 30) (30, 120000) (30,)

# %%
S = np.diag(S)
print(S.shape)
# Out:
# (30, 30)

# %%
S = S * S

# %%
correlations = V.T @ S
print(correlatigrayscaleons.shape)
# Out:
# (120000, 30)

# %%
eigenvector = correlations[:,0]
print(eigenvector.shape)
# Out:
# (120000,)

# %%
img = plt.imshow(eigenvector.reshape(400,300))
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
eigenvector = correlations[:,29]
print(eigenvector.shape)
# Out:
# (120000,)

# %%
img = plt.imshow(eigenvector.reshape(400,300))
img.set_cmap('gray')
plt.axis('off')
plt.show()
